# %%
! /opt/bin/nvidia-smi
# Out:
# Sat May  8 23:45:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip -q install gputil
# !pip -q install psutil
# !pip -q install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Gen RAM Free: 12.7 GB  | Proc size: 118.3 MB
# GPU RAM Free: 16280MB | Used: 0MB | Util   0% | Total 16280MB

# %%
# install nlp
# !pip install -qq nlp==0.2.0

# Make sure that we have a recent version of pyarrow in the session before we continue - otherwise reboot Colab to activate it
import pyarrow
# if int(pyarrow.__version__.split('.')[1]) < 16:
#     import os
#     os.kill(os.getpid(), 9)

# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-wx6qssp7
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-wx6qssp7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): transformers==4.6.0.dev0 from git+https://github.com/huggingface/transformers.git in /usr/local/lib/python3.7/dist-packages
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (3.10.1)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (0.0.8)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (4.41.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (0.0.45)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0.dev0) (3.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.6.0.dev0) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.6.0.dev0) (3.7.4.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.0.dev0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.0.dev0) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.0.dev0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.6.0.dev0) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0.dev0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0.dev0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0.dev0) (2020.12.5)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.6.0.dev0-cp37-none-any.whl size=2213074 sha256=b5d5dbeae47983356a7e25fdf2d3ff62c68c77a3c4e6970dca052cd4cabc6b84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hza3bd7i/wheels/33/eb/3b/4bf5dd835e865e472d4fc0754f35ac0edb08fe852e8f21655f
# Successfully built transformers

# %%
# imports
from transformers import (
    ReformerForMaskedLM,
    ReformerTokenizer,
    ReformerConfig,
    Trainer,
    DataCollatorForLanguageModeling,
    TrainingArguments,
    TrainerCallback,
)
import nlp
import torch
from torch.utils.data.dataset import Dataset
import matplotlib.pyplot as plt

# %%
# load the dataset
dataset = nlp.load_dataset("crime_and_punish", split="train")
# get a pretrained tokenizer
tokenizer = ReformerTokenizer.from_pretrained("google/reformer-crime-and-punishment")
tokenizer.add_special_tokens({"mask_token": '[MASK]'})
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

sequence_length = 2 ** 12  # 16384

# define our map function to reduce the dataset to one sample
def flatten_and_tokenize(batch):
  all_input_text = ["".join(batch["line"])]
  print(sequence_length)
  input_ids_dict = tokenizer(all_input_text, pad_to_max_length=True, max_length=sequence_length, truncation=True)

  # duplicate data 8 times to have have 8 examples in dataset
  for key in input_ids_dict.keys():
    input_ids_dict[key] = [4 * [x] for x in input_ids_dict[key]][0]

  return input_ids_dict

# reduce the dataset and set batch_size to all inputs
dataset = dataset.map(
  flatten_and_tokenize, batched=True, batch_size=-1, remove_columns=["line"]
)

# prepare dataset to be in torch format
dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])
print(dataset['input_ids'].shape)
print(dataset['attention_mask'].shape)
# Out:
# 4096
# 4096
# torch.Size([4, 4096])
# torch.Size([4, 4096])
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2110: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
class MLMReformerDataset(Dataset):

  def __init__(self, dataset):
    self.dataset = dataset

  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, i):
    return self.dataset['input_ids'][i]

mlm_dataset = MLMReformerDataset(dataset)
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=True, mlm_probability=0.15)

# %% [markdown]
# Next, we will define our reformer model by defining the `ReformerConfig`.
# For the sake of this notebook, the `google/reformer-enwik8` config is taken whereas the vocabulary size is adapted to be used with our tokenizer.

# %%
separate_q_k_config = {
  "attention_head_size": 128,
  "attn_layers": [
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
    "local",
  ],
  "axial_norm_std": 1.0,
  "axial_pos_embds": False,
  "chunk_size_feed_forward": 0,
  "chunk_size_lm_head": 0,
  "eos_token_id": 2,
  "feed_forward_size": 4096,
  "hidden_act": "relu",
  "hidden_dropout_prob": 0.2,
  "hidden_size": 1024,
  "initializer_range": 0.02,
  "is_decoder": False,
  "layer_norm_eps": 1e-12,
  "local_attention_probs_dropout_prob": 0.2,
  "local_attn_chunk_length": 4096,
  "local_num_chunks_after": 0,
  "local_num_chunks_before": 0,
  "lsh_attention_probs_dropout_prob": 0.1,
  "lsh_attn_chunk_length": 4096,
  "lsh_num_chunks_after": 0,
  "lsh_num_chunks_before": 0,
  "max_position_embeddings": 4096,
  "model_type": "reformer",
  "num_attention_heads": 8,
  "num_buckets": 512,
  "num_hashes": 1,
  "pad_token_id": 0,
  "vocab_size": 322  # +1 for [MASK] token
}

separate_q_k_config = ReformerConfig(**separate_q_k_config)
separate_q_k_model = ReformerForMaskedLM(separate_q_k_config)
separate_q_k_model = separate_q_k_model.train()
# define the training args
separate_q_k_training_args = {
    "num_train_epochs": 500,
    "logging_steps": 4,
    "warmup_steps": 0,
    # "weight_decay": 0.001,
    "per_device_train_batch_size": 1,
    "per_device_train_batch_size": 1,
    "logging_dir": "./logs",
    "output_dir": "./"
}

separate_q_k_training_args = TrainingArguments(**separate_q_k_training_args)
# create the trainer
separate_q_k_trainer = Trainer(
    model=separate_q_k_model,
    args=separate_q_k_training_args,
    data_collator=data_collator,
    train_dataset=mlm_dataset,
)
 
separate_steps = []
separate_loss = []
class SeparateLossCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
      log_history = state.log_history
      for index in range(len(log_history) - 1):
        log = log_history[index]
        separate_steps.append(log['step'])
        separate_loss.append(log['loss'])
      print(separate_steps, separate_loss)

separate_q_k_trainer.add_callback(SeparateLossCallback())
# train
separate_q_k_trainer.train()
# Out:
#     <div>
#
#       <progress value='2000' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [
td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.117000</td>
#     </tr>
#     <tr>
#       <td>284</td>
#       <td>1.048600</td>
#     </tr>
#     <tr>
#       <td>288</td>
#       <td>1.025600</td>
#     </tr>
#     <tr>
#       <td>292</td>
#       <td>0.986900</td>
#     </tr>
#     <tr>
#       <td>296</td>
#       <td>0.951500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.880300</td>
#     </tr>
#     <tr>
#       <td>304</td>
#       <td>0.836400</td>
#     </tr>
#     <tr>
#       <td>308</td>
#       <td>0.803800</td>
#     </tr>
#     <tr>
#       <td>312</td>
#       <td>0.761200</td>
#     </tr>
#     <tr>
#       <td>316</td>
#       <td>0.736200</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.717300</td>
#     </tr>
#     <tr>
#       <td>324</td>
#       <td>0.664900</td>
#     </tr>
#     <tr>
#       <td>328</td>
#       <td>0.614900</td>
#     </tr>
#     <tr>
#       <td>332</td>
#       <td>0.581700</td>
#     </tr>
#     <tr>
#       <td>336</td>
#       <td>0.572900</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.525400</td>
#     </tr>
#     <tr>
#       <td>344</td>
#       <td>0.508300</td>
#     </tr>
#     <tr>
#       <td>348</td>
#       <td>0.473700</td>
#     </tr>
#     <tr>
#       <td>352</td>
#       <td>0.436300</td>
#     </tr>
#     <tr>
#       <td>356</td>
#       <td>0.422300</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.386500</td>
#     </tr>
#     <tr>
#       <td>364</td>
#       <td>0.358600</td>
#     </tr>
#     <tr>
#       <td>368</td>
#       <td>0.397500</td>
#     </tr>
#     <tr>
#       <td>372</td>
#       <td>0.342700</td>
#     </tr>
#     <tr>
#       <td>376</td>
#       <td>0.329700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.318600</td>
#     </tr>
#     <tr>
#       <td>384</td>
#       <td>0.302100</td>
#     </tr>
#     <tr>
#       <td>388</td>
#       <td>0.269600</td>
#     </tr>
#     <tr>
#       <td>392</td>
#       <td>0.256600</td>
#     </tr>
#     <tr>
#       <td>396</td>
#       <td>0.234200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.237400</td>
#     </tr>
#     <tr>
#       <td>404</td>
#       <td>0.205900</td>
#     </tr>
#     <tr>
#       <td>408</td>
#       <td>0.215000</td>
#     </tr>
#     <tr>
#       <td>412</td>
#       <td>0.192800</td>
#     </tr>
#     <tr>
#       <td>416</td>
#       <td>0.178000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.184600</td>
#     </tr>
#     <tr>
#       <td>424</td>
#       <td>0.177300</td>
#     </tr>
#     <tr>
#       <td>428</td>
#       <td>0.165600</td>
#     </tr>
#     <tr>
#       <td>432</td>
#       <td>0.149100</td>
#     </tr>
#     <tr>
#       <td>436</td>
#       <td>0.147900</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.147200</td>
#     </tr>
#     <tr>
#       <td>444</td>
#       <td>0.133500</td>
#     </tr>
#     <tr>
#       <td>448</td>
#       <td>0.134600</td>
#     </tr>
#     <tr>
#       <td>452</td>
#       <td>0.121200</td>
#     </tr>
#     <tr>
#       <td>456</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.126300</td>
#     </tr>
#     <tr>
#       <td>464</td>
#       <td>0.105900</td>
#     </tr>
#     <tr>
#       <td>468</td>
#       <td>0.107300</td>
#     </tr>
#     <tr>
#       <td>472</td>
#       <td>0.099300</td>
#     </tr>
#     <tr>
#       <td>476</td>
#       <td>0.094100</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0
  ],
  "axial_norm_std": 1.0,
  "axial_pos_embds": False,
  "chunk_size_feed_forward": 0,
  "chunk_size_lm_head": 0,
  "eos_token_id": 2,
  "feed_forward_size": 4096,
  "hidden_act": "relu",
  "hidden_dropout_prob": 0.2,
  "hidden_size": 1024,
  "initializer_range": 0.02,
  "is_decoder": False,
  "layer_norm_eps": 1e-12,
  "local_attention_probs_dropout_prob": 0.2,
  "local_attn_chunk_length": 4096,
  "local_num_chunks_after": 0,
  "local_num_chunks_before": 0,
  "lsh_attention_probs_dropout_prob": 0.1,
  "lsh_attn_chunk_length": 4096,
  "lsh_num_chunks_after": 0,
  "lsh_num_chunks_before": 0,
  "max_position_embeddings": 4096,
  "model_type": "reformer",
  "num_attention_heads": 8,
  "num_buckets": 512,
  "num_hashes": 1,
  "pad_token_id": 0,
  "vocab_size": 322  # +1 for [MASK] token
}

shared_q_k_config = ReformerConfig(**shared_q_k_config)
shared_q_k_model = ReformerForMaskedLM(shared_q_k_config)
shared_q_k_model = shared_q_k_model.train()
# define the training args
shared_q_k_training_args = {
    "num_train_epochs": 500,
    "logging_steps": 4,
    "warmup_steps": 0,
    # "weight_decay": 0.001,
    "per_device_train_batch_size": 1,
    "per_device_train_batch_size": 1,
    "logging_dir": "./logs",
    "output_dir": "./"
}

shared_q_k_training_args = TrainingArguments(**shared_q_k_training_args)
# create the trainer
shared_q_k_trainer = Trainer(
    model=shared_q_k_model,
    args=shared_q_k_training_args,
    data_collator=data_collator,
    train_dataset=mlm_dataset,
)
 
shared_steps = []
shared_loss = []
class SharedLossCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
      log_history = state.log_history
      for index in range(len(log_history) - 1):
        log = log_history[index]
        shared_steps.append(log['step'])
        shared_loss.append(log['loss'])
      print(shared_steps, shared_loss)

shared_q_k_trainer.add_callback(SharedLossCallback())
# train
shared_q_k_trainer.train()
# Out:
#     <div>
#
#       <progress value='2000' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2000/2000 1:08:13, Epoch 500/500]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4</td>
#       <td>5.992500</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>5.502700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>5.378300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>5.312200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.321000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>5.253500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>5.276300</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>5.316600</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>5.283500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>5.275700</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>5.280600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>5.261600</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>5.222600</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>5.237600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>5.281400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>5.233800</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>5.254900</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>5.245800</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>5.231700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>5.206700</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>5.214200</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>5.234800</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>5.223300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>5.193700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>5.191400</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>5.189200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>5.214500</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>5.113300</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>5.131000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>5.093000</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>5.055400</td>
#     </tr>
#     <tr>
#       <td>128</td>
#       <td>5.015500</td>
#     </tr>
#     <tr>
#       <td>132</td>
#       <td>5.003700</td>
#     </tr>
#     <tr>
#       <td>136</td>
#       <td>4.882100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>4.840800</td>
#     </tr>
#     <tr>
#       <td>144</td>
#       <td>4.675600</td>
#     </tr>
#     <tr>
#       <td>148</td>
#       <td>4.591100</td>
#     </tr>
#     <tr>
#       <td>152</td>
#       <td>4.572200</td>
#     </tr>
#     <tr>
#       <td>156</td>
#       <td>4.396200</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>4.367300</td>
#     </tr>
#     <tr>
#       <td>164</td>
#       <td>4.235300</td>
#     </tr>
#     <tr>
#       <td>168</td>
#       <td>4.160500</td>
#     </tr>
#     <tr>
#       <td>172</td>
#       <td>3.978900</td>
#     </tr>
#     <tr>
#       <td>176</td>
#       <td>3.967700</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>3.842600</td>
#     </tr>
#     <tr>
#       <td>184</td>
#       <td>3.730600</td>
#     </tr>
#     <tr>
#       <td>188</td>
#       <td>3.712900</td>
#     </tr>
#     <tr>
#       <td>192</td>
#       <td>3.595800</td>
#     </tr>
#     <tr>
#       <td>196</td>
#       <td>3.521500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>3.463700</td>
#     </tr>
#     <tr>
#       <td>204</td>
#       <td>3.288800</td>
#     </tr>
#     <tr>
#       <td>208</td>
#       <td>3.256900</td>
#     </tr>
#     <tr>
#       <td>212</td>
#       <td>3.222900</td>
#     </tr>
#     <tr>
#       <td>216</td>
#       <td>3.142800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>3.066700</td>
#     </tr>
#     <tr>
#       <td>224</td>
#       <td>2.962700</td>
#     </tr>
#     <tr>
#       <td>228</td>
#       <td>2.901600</td>
#     </tr>
#     <tr>
#       <td>232</td>
#       <td>2.814900</td>
#     </tr>
#     <tr>
#       <td>236</td>
#       <td>2.770000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.727400</td>
#     </tr>
#     <tr>
#       <td>244</td>
#       <td>2.679000</td>
#     </tr>
#     <tr>
#       <td>248</td>
#       <td>2.646200</td>
#     </tr>
#     <tr>
#       <td>252</td>
#       <td>2.570400</td>
#     </tr>
#     <tr>
#       <td>256</td>
#       <td>2.435600</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>2.332600</td>
#     </tr>
#     <tr>
#       <td>264</td>
#       <td>2.387300</td>
#     </tr>
#     <tr>
#       <td>268</td>
#       <td>2.297400</td>
#     </tr>
#     <tr>
#       <td>272</td>
#       <td>2.199300</td>
#     </tr>
#     <tr>
#       <td>276</td>
#       <td>2.165000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>2.048000</td>
#     </tr>
#     <tr>
#       <td>284</td>
#       <td>2.093100</td>
#     </tr>
#     <tr>
#       <td>288</td>
#       <td>2.017000</td>
#     </tr>
#     <tr>
#       <td>292</td>
#       <td>1.943200</td>
#     </tr>
#     <tr>
#       <td>296</td>
#       <td>1.934700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.864800</td>
#     </tr>
#     <tr>
#       <td>304</td>
#       <td>1.774100</td>
#     </tr>
#     <tr>
#       <td>308</td>
#       <td>1.767200</td>
#     </tr>
#     <tr>
#       <td>312</td>
#       <td>1.566700</td>
#     </tr>
#     <tr>
#       <td>316</td>
#       <td>1.633800</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.598500</td>
#     </tr>
#     <tr>
#       <td>324</td>
#       <td>1.519600</td>
#     </tr>
#     <tr>
#       <td>328</td>
#       <td>1.446600</td>
#     </tr>
#     <tr>
#       <td>332</td>
#       <td>1.556200</td>
#     </tr>
#     <tr>
#       <td>336</td>
#       <td>1.478100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.350000</td>
#     </tr>
#     <tr>
#       <td>344</td>
#       <td>1.490600</td>
#     </tr>
#     <tr>
#       <td>348</td>
#       <td>1.263100</td>
#     </tr>
#     <tr>
#       <td>352</td>
#       <td>1.252800</td>
#     </tr>
#     <tr>
#       <td>356</td>
#       <td>1.178000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.206800</td>
#     </tr>
#     <tr>
#       <td>364</td>
#       <td>1.170000</td>
#     </tr>
#     <tr>
#       <td>368</td>
#       <td>1.110200</td>
#     </tr>
#     <tr>
#       <td>372</td>
#       <td>1.070700</td>
#     </tr>
#     <tr>
#       <td>376</td>
#       <td>0.997800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.007100</td>
#     </tr>
#     <tr>
#       <td>384</td>
#       <td>0.989600</td>
#     </tr>
#     <tr>
#       <td>388</td>
#       <td>0.895800</td>
#     </tr>
#     <tr>
#       <td>392</td>
#       <td>0.912200</td>
#     </tr>
#     <tr>
#       <td>396</td>
#       <td>0.875500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.831600</td>
#     </tr>
#     <tr>
#       <td>404</td>
#       <td>0.863000</td>
#     </tr>
#     <tr>
#       <td>408</td>
#       <td>0.800100</td>
#     </tr>
#     <tr>
#       <td>412</td>
#       <td>0.770000</td>
#     </tr>
#     <tr>
#       <td>416</td>
#       <td>0.778100</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.770100</td>
#     </tr>
#     <tr>
#       <td>424</td>
#       <td>0.725200</td>
#     </tr>
#     <tr>
#       <td>428</td>
#       <td>0.709600</td>
#     </tr>
#     <tr>
#       <td>432</td>
#       <td>0.634400</td>
#     </tr>
#     <tr>
#       <td>436</td>
#       <td>0.638800</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.605300</td>
#     </tr>
#     <tr>
#       <td>444</td>
#       <td>0.640400</td>
#     </tr>
#     <tr>
#       <td>448</td>
#       <td>0.611500</td>
#     </tr>
#     <tr>
#       <td>452</td>
#       <td>0.553300</td>
#     </tr>
#     <tr>
#       <td>456</td>
#       <td>0.571000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.543700</td>
#     </tr>
#     <tr>
#       <td>464</td>
#       <td>0.541100</td>
#     </tr>
#     <tr>
#       <td>468</td>
#       <td>0.534300</td>
#     </tr>
#     <tr>
#       <td>472</td>
#       <td>0.471800</td>
#     </tr>
#     <tr>
#       <td>476</td>
#       <td>0.483000</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.438800</td>
#     </tr>
#     <tr>
#       <td>484</td>
#       <td>0.406300</td>
#     </tr>
#     <tr>
#       <td>488</td>
#       <td>0.365100</td>
#     </tr>
#     <tr>
#       <td>492</td>
#       <td>0.374100</td>
#     </tr>
#     <tr>
#       <td>496</td>
#       <td>0.383800</td>
# [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124, 128, 132, 136, 140, 144, 148, 152, 156, 160, 164, 168, 172, 176, 180, 184, 188, 192, 196, 200, 204, 208, 212, 216, 220, 224, 228, 232, 236, 240, 244, 248, 252, 256, 260, 264, 268, 272, 276, 280, 284, 288, 292, 296, 300, 304, 308, 312, 316, 320, 324, 328, 332, 336, 340, 344, 348, 352, 356, 360, 364, 368, 372, 376, 380, 384, 388, 392, 396, 400, 404, 408, 412, 416, 420, 424, 428, 432, 436, 440, 444, 448, 452, 456, 460, 464, 468, 472, 476, 480, 484, 488, 492, 496, 500, 504, 508, 512, 516, 520, 524, 528, 532, 536, 540, 544, 548, 552, 556, 560, 564, 568, 572, 576, 580, 584, 588, 592, 596, 600, 604, 608, 612, 616, 620, 624, 628, 632, 636, 640, 644, 648, 652, 656, 660, 664, 668, 672, 676, 680, 684, 688, 692, 696, 700, 704, 708, 712, 716, 720, 724, 728, 732, 736, 740, 744, 748, 752, 756, 760, 764, 768, 772, 776, 780, 784, 788, 792, 796, 800, 804, 808, 812, 816, 820, 824, 828, 832, 836, 840, 844, 848, 852, 856, 860, 864, 868, 872, 876, 880, 884, 888, 892, 896, 900, 904,
 1.2631, 1.2528, 1.178, 1.2068, 1.17, 1.1102, 1.0707, 0.9978, 1.0071, 0.9896, 0.8958, 0.9122, 0.8755, 0.8316, 0.863, 0.8001, 0.77, 0.7781, 0.7701, 0.7252, 0.7096, 0.6344, 0.6388, 0.6053, 0.6404, 0.6115, 0.5533, 0.571, 0.5437, 0.5411, 0.5343, 0.4718, 0.483, 0.4388, 0.4063, 0.3651, 0.3741, 0.3838, 0.3509, 0.3809, 0.3624, 0.3586, 0.3422, 0.3219, 0.3191, 0.291, 0.3079, 0.2686, 0.2878, 0.2803, 0.2346, 0.307, 0.2501, 0.2541, 0.1962, 0.2636, 0.2502, 0.2434, 0.2317, 0.2276, 0.2357, 0.2043, 0.2174, 0.1973, 0.1835, 0.1903, 0.1978, 0.1891, 0.1539, 0.1866, 0.139, 0.1658, 0.1701, 0.1554, 0.1604, 0.2006, ...
# TrainOutput(global_step=2000, training_loss=0.7596611221060157, metrics={'train_runtime': 4095.1724, 'train_samples_per_second': 0.488, 'total_flos': 0, 'epoch': 500.0, 'init_mem_cpu_alloc_delta': 0, 'init_mem_gpu_alloc_delta': 575104512, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': -534102016, 'train_mem_gpu_alloc_delta': 1725305856, 'train_mem_cpu_peaked_delta': 534274048, 'train_mem_gpu_peaked_delta': 4341564928})

# %%
shared_q_k_4_config = {
  "attention_head_size": 128,
  "attn_layers": [
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
  ],
  "axial_norm_std": 1.0,
  "axial_pos_embds": False,
  "chunk_size_feed_forward": 0,
  "chunk_size_lm_head": 0,
  "eos_token_id": 2,
  "feed_forward_size": 4096,
  "hidden_act": "relu",
  "hidden_dropout_prob": 0.2,
  "hidden_size": 1024,
  "initializer_range": 0.02,
  "is_decoder": False,
  "layer_norm_eps": 1e-12,
  "local_attention_probs_dropout_prob": 0.2,
  "local_attn_chunk_length": 4096,
  "local_num_chunks_after": 0,
  "local_num_chunks_before": 0,
  "lsh_attention_probs_dropout_prob": 0.1,
  "lsh_attn_chunk_length": 4096,
  "lsh_num_chunks_after": 0,
  "lsh_num_chunks_before": 0,
  "max_position_embeddings": 4096,
  "model_type": "reformer",
  "num_attention_heads": 8,
  "num_buckets": 512,
  "num_hashes": 4,
  "pad_token_id": 0,
  "vocab_size": 322  # +1 for [MASK] token
}

shared_q_k_4_config = ReformerConfig(**shared_q_k_4_config)
shared_q_k_4_model = ReformerForMaskedLM(shared_q_k_4_config)
shared_q_k_4_model = shared_q_k_4_model.train()
# define the training args
shared_q_k_4_training_args = {
    "num_train_epochs": 200,
    "logging_steps": 4,
    "warmup_steps": 0,
    # "weight_decay": 0.001,
    "per_device_train_batch_size": 1,
    "per_device_train_batch_size": 1,
    "logging_dir": "./logs",
    "output_dir": "./"
}

shared_q_k_4_training_args = TrainingArguments(**shared_q_k_4_training_args)
# create the trainer
shared_q_k_4_trainer = Trainer(
    model=shared_q_k_4_model,
    args=shared_q_k_4_training_args,
    data_collator=data_collator,
    train_dataset=mlm_dataset,
)
 
shared_q_k_4_steps = []
shared_q_k_4_loss = []
class SharedLossCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
      log_history = state.log_history
      for index in range(len(log_history) - 1):
        log = log_history[index]
        shared_q_k_4_steps.append(log['step'])
        shared_q_k_4_loss.append(log['loss'])
      print(shared_steps, shared_loss)

shared_q_k_4_trainer.add_callback(SharedLossCallback())
# train
shared_q_k_4_trainer.train()

# %%
shared_q_k_8_config = {
  "attention_head_size": 128,
  "attn_layers": [
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
    "lsh",
  ],
  "axial_norm_std": 1.0,
  "axial_pos_embds": False,
  "chunk_size_feed_forward": 0,
  "chunk_size_lm_head": 0,
  "eos_token_id": 2,
  "feed_forward_size": 4096,
  "hidden_act": "relu",
  "hidden_dropout_prob": 0.2,
  "hidden_size": 1024,
  "initializer_range": 0.02,
  "is_decoder": False,
  "layer_norm_eps": 1e-12,
  "local_attention_probs_dropout_prob": 0.2,
  "local_attn_chunk_length": 4096,
  "local_num_chunks_after": 0,
  "local_num_chunks_before": 0,
  "lsh_attention_probs_dropout_prob": 0.1,
  "lsh_attn_chunk_length": 4096,
  "lsh_num_chunks_after": 0,
  "lsh_num_chunks_before": 0,
  "max_position_embeddings": 4096,
  "model_type": "reformer",
  "num_attention_heads": 8,
  "num_buckets": 512,
  "num_hashes": 4,
  "pad_token_id": 0,
  "vocab_size": 322  # +1 for [MASK] token
}

shared_q_k_8_config = ReformerConfig(**shared_q_k_8_config)
shared_q_k_8_model = ReformerForMaskedLM(shared_q_k_8_config)
shared_q_k_8_model = shared_q_k_8_model.train()
# define the training args
shared_q_k_8_training_args = {
    "num_train_epochs": 200,
    "logging_steps": 4,
    "warmup_steps": 0,
    # "weight_decay": 0.001,
    "per_device_train_batch_size": 1,
    "per_device_train_batch_size": 1,
    "logging_dir": "./logs",
    "output_dir": "./"
}

shared_q_k_8_training_args = TrainingArguments(**shared_q_k_8_training_args)
# create the trainer
shared_q_k_8_trainer = Trainer(
    model=shared_q_k_8_model,
    args=shared_q_k_8_training_args,
    data_collator=data_collator,
    train_dataset=mlm_dataset,
)
 
shared_q_k_8_steps = []
shared_q_k_8_loss = []
class SharedLossCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
      log_history = state.log_history
      for index in range(len(log_history) - 1):
        log = log_history[index]
        shared_q_k_8_steps.append(log['step'])
        shared_q_k_8_loss.append(log['loss'])
      print(shared_steps, shared_loss)

shared_q_k_8_trainer.add_callback(SharedLossCallback())
# train
shared_q_k_8_trainer.train()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(shared_steps, shared_loss, c="r", label="shared QK")
ax.plot(separate_steps, separate_loss, c="g", label="seperate QK")
ax.legend()
ax.set_xlabel("Steps", fontsize=12)
ax.set_ylabel("Loss", fontsize=12)
ax.set_title("shared query-key space - crime_and_punish", fontsize=16)
plt.show()
